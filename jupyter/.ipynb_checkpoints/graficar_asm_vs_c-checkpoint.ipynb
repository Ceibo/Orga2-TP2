# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set_style("darkgrid")
from sklearn import linear_model
import random

import warnings
warnings.filterwarnings('ignore')

# %%
# Levanto los datos

df = pd.read_csv('media_sin_outliers_data_solver_project.csv')

# %%
# Gráficos los datos
sns.set(font_scale=1.9) 
sns.tsplot(time=df['tamanio'], data=df['data_c'],condition=u"Tiempos C")#, interpolate=False)
sns.tsplot(time=df['tamanio'], data=df['data_asm'], color='r',condition=u"Tiempos ASM")#, interpolate=False)
sns.plt.ylabel(u'Ticks', fontsize=24, fontweight='bold')
sns.plt.xlabel(u'Tamaño', fontsize=24, fontweight='bold')
sns.plt.show()

# %%
# Limpio los outliers

#def mascara_outliers(s):
 #   return abs(s - s.mean()) <= 2*s.std()
    
mascara_c = mascara_outliers(df['c'])
df_c = df[mascara_c]
mascara_asm = mascara_outliers(df['asm'])
df_asm = df[mascara_asm]
print("Decripción de los datos podados c (ignorar los de asm))")
print(df_c.describe())
sns.tsplot(time=df_c['N repeticion'], data=df_c['c'], interpolate=False)
sns.plt.show()
print("Decripción de los datos podados asm (ignorar los de c))")
print(df_asm.describe())
sns.tsplot(time=df_asm['N repeticion'], data=df_asm['asm'], interpolate=False)
sns.plt.show()
# Out:
# Decripción de los datos podados c
#        N repeticion             c           asm
# count     96.000000     96.000000     96.000000
# mean      51.833333  54054.041667  20447.541667
# std       28.763525   7351.569451   4172.376967
# min        2.000000  43660.000000  15400.000000
# 25%       27.750000  48840.000000  17738.000000
# 50%       52.500000  51914.000000  19724.000000
# 75%       76.250000  57023.000000  22106.000000
# max      100.000000  72516.000000  41608.000000
# Decripción de los datos podados asm
#        N repeticion             c          asm
# count     96.000000     96.000000     96.00000
# mean      50.635417  54937.843750  19752.25000
# std       29.202783   8885.793962   2625.76807
# min        1.000000  43660.000000  15400.00000
# 25%       24.750000  48840.000000  17716.00000
# 50%       51.500000  51914.000000  19464.00000
# 75%       75.250000  57581.000000  21499.00000
# max      100.000000  85816.000000  26928.00000

# %%
# Un par de cosas más de pandas

years = [2004]*6 + [2005]*6 + [2006]*6
delays = list(np.random.randn(6)+80) + list(np.random.randn(6)+5) + list(np.random.randn(6)+50)
delays[2] = 5
delays[7] = 80

df1 = pd.DataFrame({
    'year': years,
    'delay': delays
})

df1
# Out:
#         delay  year
# 0   80.821911  2004
# 1   81.994264  2004
# 2    5.000000  2004
# 3   77.742141  2004
# 4   80.080482  2004
# 5   80.356484  2004
# 6    4.082986  2005
# 7   80.000000  2005
# 8    5.537343  2005
# 9    5.836535  2005
# 10   5.402303  2005
# 11   5.086106  2005
# 12  50.606251  2006
# 13  50.135174  2006
# 14  50.751529  2006
# 15  50.293271  2006
# 16  51.094942  2006
# 17  48.922509  2006

# %%
# Groupby y sacar outliers

mascara = df1.groupby('year')['delay'].apply(mascara_outliers)
df1 = df1[mascara]
df1
# Out:
#         delay  year
# 0   80.821911  2004
# 1   81.994264  2004
# 3   77.742141  2004
# 4   80.080482  2004
# 5   80.356484  2004
# 6    4.082986  2005
# 8    5.537343  2005
# 9    5.836535  2005
# 10   5.402303  2005
# 11   5.086106  2005
# 12  50.606251  2006
# 13  50.135174  2006
# 14  50.751529  2006
# 15  50.293271  2006
# 16  51.094942  2006
# 17  48.922509  2006

# %%
# Groupby y calcular promedio

promedio = df1.groupby('year').aggregate(['mean', 'std', 'count'])
promedio
# Out:
#           delay
#            mean       std count
# year
# 2004  80.199056  1.556117     5
# 2005   5.189055  0.674536     5
# 2006  50.300613  0.755552     6
